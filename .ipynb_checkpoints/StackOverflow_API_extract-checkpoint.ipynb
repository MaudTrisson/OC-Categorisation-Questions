# %%
import mlflow
import mlflow.sklearn
from time import time
from sklearn.metrics import (accuracy_score, precision_score, recall_score, f1_score,
                             hamming_loss, jaccard_score, confusion_matrix, roc_curve, auc)
import matplotlib.pyplot as plt
import numpy as np


import requests
import time
import csv
import pandas as pd
from datetime import datetime, timedelta

# %% [markdown]
# ## Récupération des données via l'API

# %%
# Fonction pour récupérer les questions avec filtrage par dates (fromdate, todate)
def fetch_questions(page, pagesize, key, fromdate, todate, retries=3):
    url = "https://api.stackexchange.com/2.3/questions"
    params = {
        "page": page,
        "pagesize": pagesize,
        "order": "desc",
        "sort": "votes",
        "site": "stackoverflow",
        "filter": "withbody",  # Ajouter le filtre pour récupérer le body
        "key": key,  # Inclure la clé API
        "fromdate": int(fromdate.timestamp()),  # Convertir en timestamp Unix
        "todate": int(todate.timestamp())  # Convertir en timestamp Unix
    }

    print(f"Sending request for page {page} with params: {params}")

    for attempt in range(retries):
        try:
            response = requests.get(url, params=params)
            # Vérifier si le statut est 429 Too Many Requests
            if response.status_code == 429:
                retry_after = int(response.headers.get('Retry-After', 60))  # Par défaut attendre 60s si "Retry-After" absent
                print(f"Too many requests. Retrying after {retry_after} seconds.")
                time.sleep(retry_after)
                return fetch_questions(page, pagesize, key, fromdate, todate, retries)
            response.raise_for_status()  # Raises HTTPError for bad responses
            return response.json()

        except requests.exceptions.HTTPError as err:
            if response.status_code == 400:  # Gérer les erreurs 400
                print(f"HTTP error 400 occurred: {err}. Retrying in 300 seconds...")
                time.sleep(300)  # Pause de 300 secondes avant de réessayer
            else:
                print(f"HTTP error occurred: {err}")
                return None  # Autres erreurs, abandonner cette requête
    print(f"Failed after {retries} attempts for page {page}. Skipping to the next page.")
    return None  # Retourner None après avoir épuisé les tentatives

# Fonction pour filtrer les questions selon les critères spécifiques
def filter_questions(questions):
    filtered = []
    
    # Afficher la réponse brute pour vérifier combien de questions sont récupérées
    print(f"Total questions fetched (before filtering): {len(questions)}")
    
    for idx, question in enumerate(questions):
        # Appliquer les filtres donnés dans l'image:
        # Pour le diagnostic, je désactive temporairement certains filtres
        if (
            question['view_count'] > 0 and
            # 'favorite_count' in question and question['favorite_count'] is not None and  # Filtre désactivé pour test
            question['answer_count'] > 0 and
            len(question['tags']) >= 5 and  # Vérifie qu'il y a au moins 5 tags
            'title' in question and 'body' in question  # Assure qu'il y a un titre et un body
        ):

            # Convertir le timestamp creation_date en date lisible
            creation_date = datetime.utcfromtimestamp(question['creation_date']).strftime('%Y-%m-%d %H:%M:%S')
            
            filtered.append({
                "title": question['title'],
                "body": question['body'],
                "link": question['link'],
                "view_count": question['view_count'],
                "score": question['score'],
                # "favorite_count": question.get('favorite_count', 0),  # Filtre désactivé pour test
                "answer_count": question['answer_count'],  # Ajout du nombre de réponses
                "tags": ','.join(question['tags']),
                "creation_date": creation_date  # Ajouter la date de création
            })
    
    # Afficher combien de questions restent après filtrage
    print(f"Total questions after filtering: {len(filtered)}")
    
    return filtered

# Fonction principale pour récupérer les questions semaine par semaine
def main():
    all_questions = []
    total_questions = 0  # Compteur global pour le nombre total de questions récupérées
    pagesize = 100  # Taille des pages
    max_questions = 50000
    api_key = "rl_Vssw9iwuVvjuT8agzZnVhH9J3"  # Replace with your actual API key

    # Calculer la plage de temps pour l'année n-1, semaine par semaine
    today = datetime.today()
    year_n_1 = today.year - 1  # Calculer l'année n-1

    # Commencer au début de l'année n-1
    start_date = datetime(year_n_1, 1, 1)
    end_date = datetime(year_n_1, 12, 31)

    current_date = start_date

    while current_date <= end_date:
        # Calculer la fin de la semaine
        next_week = current_date + timedelta(days=7)
        last_day_of_week = min(next_week, end_date)
        
        page = 1
        while True:
            data = fetch_questions(page, pagesize, api_key, current_date, last_day_of_week)
            if data is None:
                # Si une erreur survient après plusieurs tentatives sur une page, passer à la page suivante
                print(f"Skipping page {page} for the week starting {current_date.strftime('%d %B %Y')} due to repeated errors.")
                page += 1
                continue  # Passer à la page suivante si une page échoue après plusieurs tentatives

            if 'items' not in data or len(data['items']) == 0:
                print("No more questions to fetch.")
                break

            # Appliquer le filtrage avec les critères
            filtered_questions = filter_questions(data['items'])
            all_questions.extend(filtered_questions)

            # Mettre à jour le compteur global
            total_questions += len(filtered_questions)
            print(f"Fetched {len(filtered_questions)} questions on page {page} for {current_date.strftime('%d %B %Y')}.")
            print(f"Total questions collected so far: \033[1m{total_questions}\033[0m")

            if len(all_questions) >= max_questions:
                print("Reached the maximum number of questions to fetch.")
                break

            # Vérifier si l'API a encore des pages à retourner
            if not data.get('has_more', False):
                print("No more pages to fetch.")
                break

            # Respect API rate limits with dynamic sleep
            retry_after = int(data.get('backoff', 1))
            if retry_after > 1:
                print(f"Pausing for {retry_after} seconds to respect rate limits.")
            time.sleep(retry_after)

            page += 1  # Passer à la page suivante

        if len(all_questions) >= max_questions:
            break

        # Passer à la semaine suivante
        current_date = next_week

    # Save the questions to a CSV file
    csv_file = 'filtered_questions_year_n_1.csv'
    csv_columns = ["title", "body", "link", "view_count", "score", "answer_count", "tags", "creation_date"]
    
    with open(csv_file, 'w', newline='', encoding='utf-8') as csvfile:
        writer = csv.DictWriter(csvfile, fieldnames=csv_columns)
        writer.writeheader()
        for question in all_questions:
            writer.writerow(question)

    print(f"Collected {total_questions} questions and saved to {csv_file}")

if __name__ == "__main__":
    main()
# Out:
# Sending request for page 1 with params: {'page': 1, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 17
# Fetched 17 questions on page 1 for 01 January 2023.
# Total questions collected so far: 17
# Sending request for page 2 with params: {'page': 2, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 16
# Fetched 16 questions on page 2 for 01 January 2023.
# Total questions collected so far: 33
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 3 with params: {'page': 3, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 15
# Fetched 15 questions on page 3 for 01 January 2023.
# Total questions collected so far: 48
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 4 with params: {'page': 4, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 14
# Fetched 14 questions on page 4 for 01 January 2023.
# Total questions collected so far: 62
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 5 with params: {'page': 5, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 11
# Fetched 11 questions on page 5 for 01 January 2023.
# Total questions collected so far: 73
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 6 with params: {'page': 6, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 10
# Fetched 10 questions on page 6 for 01 January 2023.
# Total questions collected so far: 83
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 7 with params: {'page': 7, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 12
# Fetched 12 questions on page 7 for 01 January 2023.
# Total questions collected so far: 95
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 8 with params: {'page': 8, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 14
# Fetched 14 questions on page 8 for 01 January 2023.
# Total questions collected so far: 109
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 9 with params: {'page': 9, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 16
# Fetched 16 questions on page 9 for 01 January 2023.
# Total questions collected so far: 125
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 10 with params: {'page': 10, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 16
# Fetched 16 questions on page 10 for 01 January 2023.
# Total questions collected so far: 141
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 11 with params: {'page': 11, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 21
# Fetched 21 questions on page 11 for 01 January 2023.
# Total questions collected so far: 162
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 12 with params: {'page': 12, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 20
# Fetched 20 questions on page 12 for 01 January 2023.
# Total questions collected so far: 182
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 13 with params: {'page': 13, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 16
# Fetched 16 questions on page 13 for 01 January 2023.
# Total questions collected so far: 198
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 14 with params: {'page': 14, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 15
# Fetched 15 questions on page 14 for 01 January 2023.
# Total questions collected so far: 213
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 15 with params: {'page': 15, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 11
# Fetched 11 questions on page 15 for 01 January 2023.
# Total questions collected so far: 224
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 16 with params: {'page': 16, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# HTTP error 400 occurred: 400 Client Error: Bad Request for url: https://api.stackexchange.com/2.3/questions?page=16&pagesize=100&order=desc&sort=votes&site=stackoverflow&filter=withbody&key=rl_Vssw9iwuVvjuT8agzZnVhH9J3&fromdate=1672527600&todate=1673132400. Retrying in 300 seconds...
# Total questions fetched (before filtering): 100
# Total questions after filtering: 13
# Fetched 13 questions on page 16 for 01 January 2023.
# Total questions collected so far: 237
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 17 with params: {'page': 17, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 15
# Fetched 15 questions on page 17 for 01 January 2023.
# Total questions collected so far: 252
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 18 with params: {'page': 18, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 20
# Fetched 20 questions on page 18 for 01 January 2023.
# Total questions collected so far: 272
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 19 with params: {'page': 19, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 19
# Fetched 19 questions on page 19 for 01 January 2023.
# Total questions collected so far: 291
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 20 with params: {'page': 20, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 14
# Fetched 14 questions on page 20 for 01 January 2023.
# Total questions collected so far: 305
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 21 with params: {'page': 21, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 19
# Fetched 19 questions on page 21 for 01 January 2023.
# Total questions collected so far: 324
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 22 with params: {'page': 22, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 12
# Fetched 12 questions on page 22 for 01 January 2023.
# Total questions collected so far: 336
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 23 with params: {'page': 23, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 18
# Fetched 18 questions on page 23 for 01 January 2023.
# Total questions collected so far: 354
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 24 with params: {'page': 24, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 16
# Fetched 16 questions on page 24 for 01 January 2023.
# Total questions collected so far: 370
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 25 with params: {'page': 25, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 12
# Fetched 12 questions on page 25 for 01 January 2023.
# Total questions collected so far: 382
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 26 with params: {'page': 26, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 19
# Fetched 19 questions on page 26 for 01 January 2023.
# Total questions collected so far: 401
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 27 with params: {'page': 27, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 11
# Fetched 11 questions on page 27 for 01 January 2023.
# Total questions collected so far: 412
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 28 with params: {'page': 28, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 14
# Fetched 14 questions on page 28 for 01 January 2023.
# Total questions collected so far: 426
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 29 with params: {'page': 29, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 8
# Fetched 8 questions on page 29 for 01 January 2023.
# Total questions collected so far: 434
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 30 with params: {'page': 30, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 14
# Fetched 14 questions on page 30 for 01 January 2023.
# Total questions collected so far: 448
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 31 with params: {'page': 31, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 16
# Fetched 16 questions on page 31 for 01 January 2023.
# Total questions collected so far: 464
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 32 with params: {'page': 32, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# HTTP error 400 occurred: 400 Client Error: Bad Request for url: https://api.stackexchange.com/2.3/questions?page=32&pagesize=100&order=desc&sort=votes&site=stackoverflow&filter=withbody&key=rl_Vssw9iwuVvjuT8agzZnVhH9J3&fromdate=1672527600&todate=1673132400. Retrying in 300 seconds...
# Total questions fetched (before filtering): 100
# Total questions after filtering: 13
# Fetched 13 questions on page 32 for 01 January 2023.
# Total questions collected so far: 477
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 33 with params: {'page': 33, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 14
# Fetched 14 questions on page 33 for 01 January 2023.
# Total questions collected so far: 491
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 34 with params: {'page': 34, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 12
# Fetched 12 questions on page 34 for 01 January 2023.
# Total questions collected so far: 503
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 35 with params: {'page': 35, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 15
# Fetched 15 questions on page 35 for 01 January 2023.
# Total questions collected so far: 518
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 36 with params: {'page': 36, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 14
# Fetched 14 questions on page 36 for 01 January 2023.
# Total questions collected so far: 532
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 37 with params: {'page': 37, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 10
# Fetched 10 questions on page 37 for 01 January 2023.
# Total questions collected so far: 542
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 38 with params: {'page': 38, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 12
# Fetched 12 questions on page 38 for 01 January 2023.
# Total questions collected so far: 554
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 39 with params: {'page': 39, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 13
# Fetched 13 questions on page 39 for 01 January 2023.
# Total questions collected so far: 567
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 40 with params: {'page': 40, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 12
# Fetched 12 questions on page 40 for 01 January 2023.
# Total questions collected so far: 579
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 41 with params: {'page': 41, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 11
# Fetched 11 questions on page 41 for 01 January 2023.
# Total questions collected so far: 590
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 42 with params: {'page': 42, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 12
# Fetched 12 questions on page 42 for 01 January 2023.
# Total questions collected so far: 602
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 43 with params: {'page': 43, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 9
# Fetched 9 questions on page 43 for 01 January 2023.
# Total questions collected so far: 611
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 44 with params: {'page': 44, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 11
# Fetched 11 questions on page 44 for 01 January 2023.
# Total questions collected so far: 622
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 45 with params: {'page': 45, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 16
# Fetched 16 questions on page 45 for 01 January 2023.
# Total questions collected so far: 638
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 46 with params: {'page': 46, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 14
# Fetched 14 questions on page 46 for 01 January 2023.
# Total questions collected so far: 652
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 47 with params: {'page': 47, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 11
# Fetched 11 questions on page 47 for 01 January 2023.
# Total questions collected so far: 663
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 48 with params: {'page': 48, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 12
# Fetched 12 questions on page 48 for 01 January 2023.
# Total questions collected so far: 675
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 49 with params: {'page': 49, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 18
# Fetched 18 questions on page 49 for 01 January 2023.
# Total questions collected so far: 693
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 50 with params: {'page': 50, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 11
# Fetched 11 questions on page 50 for 01 January 2023.
# Total questions collected so far: 704
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 51 with params: {'page': 51, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 13
# Fetched 13 questions on page 51 for 01 January 2023.
# Total questions collected so far: 717
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 52 with params: {'page': 52, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 11
# Fetched 11 questions on page 52 for 01 January 2023.
# Total questions collected so far: 728
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 53 with params: {'page': 53, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 9
# Fetched 9 questions on page 53 for 01 January 2023.
# Total questions collected so far: 737
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 54 with params: {'page': 54, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 12
# Fetched 12 questions on page 54 for 01 January 2023.
# Total questions collected so far: 749
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 55 with params: {'page': 55, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 13
# Fetched 13 questions on page 55 for 01 January 2023.
# Total questions collected so far: 762
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 56 with params: {'page': 56, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 18
# Fetched 18 questions on page 56 for 01 January 2023.
# Total questions collected so far: 780
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 57 with params: {'page': 57, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 10
# Fetched 10 questions on page 57 for 01 January 2023.
# Total questions collected so far: 790
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 58 with params: {'page': 58, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 12
# Fetched 12 questions on page 58 for 01 January 2023.
# Total questions collected so far: 802
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 59 with params: {'page': 59, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 9
# Fetched 9 questions on page 59 for 01 January 2023.
# Total questions collected so far: 811
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 60 with params: {'page': 60, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 11
# Fetched 11 questions on page 60 for 01 January 2023.
# Total questions collected so far: 822
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 61 with params: {'page': 61, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 15
# Fetched 15 questions on page 61 for 01 January 2023.
# Total questions collected so far: 837
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 62 with params: {'page': 62, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 6
# Fetched 6 questions on page 62 for 01 January 2023.
# Total questions collected so far: 843
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 63 with params: {'page': 63, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 13
# Fetched 13 questions on page 63 for 01 January 2023.
# Total questions collected so far: 856
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 64 with params: {'page': 64, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 11
# Fetched 11 questions on page 64 for 01 January 2023.
# Total questions collected so far: 867
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 65 with params: {'page': 65, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 17
# Fetched 17 questions on page 65 for 01 January 2023.
# Total questions collected so far: 884
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 66 with params: {'page': 66, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 15
# Fetched 15 questions on page 66 for 01 January 2023.
# Total questions collected so far: 899
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 67 with params: {'page': 67, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 7
# Fetched 7 questions on page 67 for 01 January 2023.
# Total questions collected so far: 906
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 68 with params: {'page': 68, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 14
# Fetched 14 questions on page 68 for 01 January 2023.
# Total questions collected so far: 920
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 69 with params: {'page': 69, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 12
# Fetched 12 questions on page 69 for 01 January 2023.
# Total questions collected so far: 932
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 70 with params: {'page': 70, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 18
# Fetched 18 questions on page 70 for 01 January 2023.
# Total questions collected so far: 950
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 71 with params: {'page': 71, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 10
# Fetched 10 questions on page 71 for 01 January 2023.
# Total questions collected so far: 960
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 72 with params: {'page': 72, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 15
# Fetched 15 questions on page 72 for 01 January 2023.
# Total questions collected so far: 975
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 73 with params: {'page': 73, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 19
# Fetched 19 questions on page 73 for 01 January 2023.
# Total questions collected so far: 994
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 74 with params: {'page': 74, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 9
# Fetched 9 questions on page 74 for 01 January 2023.
# Total questions collected so far: 1003
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 75 with params: {'page': 75, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 20
# Fetched 20 questions on page 75 for 01 January 2023.
# Total questions collected so far: 1023
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 76 with params: {'page': 76, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 17
# Fetched 17 questions on page 76 for 01 January 2023.
# Total questions collected so far: 1040
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 77 with params: {'page': 77, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 11
# Fetched 11 questions on page 77 for 01 January 2023.
# Total questions collected so far: 1051
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 78 with params: {'page': 78, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 10
# Fetched 10 questions on page 78 for 01 January 2023.
# Total questions collected so far: 1061
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 79 with params: {'page': 79, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 15
# Fetched 15 questions on page 79 for 01 January 2023.
# Total questions collected so far: 1076
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 80 with params: {'page': 80, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 7
# Fetched 7 questions on page 80 for 01 January 2023.
# Total questions collected so far: 1083
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 81 with params: {'page': 81, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 9
# Fetched 9 questions on page 81 for 01 January 2023.
# Total questions collected so far: 1092
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 82 with params: {'page': 82, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 16
# Fetched 16 questions on page 82 for 01 January 2023.
# Total questions collected so far: 1108
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 83 with params: {'page': 83, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 13
# Fetched 13 questions on page 83 for 01 January 2023.
# Total questions collected so far: 1121
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 84 with params: {'page': 84, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 10
# Fetched 10 questions on page 84 for 01 January 2023.
# Total questions collected so far: 1131
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 85 with params: {'page': 85, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 16
# Fetched 16 questions on page 85 for 01 January 2023.
# Total questions collected so far: 1147
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 86 with params: {'page': 86, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 12
# Fetched 12 questions on page 86 for 01 January 2023.
# Total questions collected so far: 1159
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 87 with params: {'page': 87, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 12
# Fetched 12 questions on page 87 for 01 January 2023.
# Total questions collected so far: 1171
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 88 with params: {'page': 88, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 14
# Fetched 14 questions on page 88 for 01 January 2023.
# Total questions collected so far: 1185
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 89 with params: {'page': 89, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 8
# Fetched 8 questions on page 89 for 01 January 2023.
# Total questions collected so far: 1193
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 90 with params: {'page': 90, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 15
# Fetched 15 questions on page 90 for 01 January 2023.
# Total questions collected so far: 1208
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 91 with params: {'page': 91, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 9
# Fetched 9 questions on page 91 for 01 January 2023.
# Total questions collected so far: 1217
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 92 with params: {'page': 92, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 11
# Fetched 11 questions on page 92 for 01 January 2023.
# Total questions collected so far: 1228
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 93 with params: {'page': 93, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 13
# Fetched 13 questions on page 93 for 01 January 2023.
# Total questions collected so far: 1241
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 94 with params: {'page': 94, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 11
# Fetched 11 questions on page 94 for 01 January 2023.
# Total questions collected so far: 1252
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 95 with params: {'page': 95, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 7
# Fetched 7 questions on page 95 for 01 January 2023.
# Total questions collected so far: 1259
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 96 with params: {'page': 96, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 17
# Fetched 17 questions on page 96 for 01 January 2023.
# Total questions collected so far: 1276
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 97 with params: {'page': 97, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 9
# Fetched 9 questions on page 97 for 01 January 2023.
# Total questions collected so far: 1285
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 98 with params: {'page': 98, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 11
# Fetched 11 questions on page 98 for 01 January 2023.
# Total questions collected so far: 1296
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 99 with params: {'page': 99, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 18
# Fetched 18 questions on page 99 for 01 January 2023.
# Total questions collected so far: 1314
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 100 with params: {'page': 100, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 13
# Fetched 13 questions on page 100 for 01 January 2023.
# Total questions collected so far: 1327
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 101 with params: {'page': 101, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 17
# Fetched 17 questions on page 101 for 01 January 2023.
# Total questions collected so far: 1344
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 102 with params: {'page': 102, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 15
# Fetched 15 questions on page 102 for 01 January 2023.
# Total questions collected so far: 1359
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 103 with params: {'page': 103, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1672527600, 'todate': 1673132400}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 11
# Fetched 11 questions on page 103 for 01 January 2023.
# Total questions collected so far: 1370
# Pausing for 10 seconds to respect rate limits.
# ...
# Sending request for page 26 with params: {'page': 26, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1685224800, 'todate': 1685829600}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 11
# Fetched 11 questions on page 26 for 28 May 2023.
# Total questions collected so far: 49638
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 27 with params: {'page': 27, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1685224800, 'todate': 1685829600}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 15
# Fetched 15 questions on page 27 for 28 May 2023.
# Total questions collected so far: 49653
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 28 with params: {'page': 28, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1685224800, 'todate': 1685829600}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 11
# Fetched 11 questions on page 28 for 28 May 2023.
# Total questions collected so far: 49664
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 29 with params: {'page': 29, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1685224800, 'todate': 1685829600}
# HTTP error 400 occurred: 400 Client Error: Bad Request for url: https://api.stackexchange.com/2.3/questions?page=29&pagesize=100&order=desc&sort=votes&site=stackoverflow&filter=withbody&key=rl_Vssw9iwuVvjuT8agzZnVhH9J3&fromdate=1685224800&todate=1685829600. Retrying in 300 seconds...
# Total questions fetched (before filtering): 100
# Total questions after filtering: 8
# Fetched 8 questions on page 29 for 28 May 2023.
# Total questions collected so far: 49672
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 30 with params: {'page': 30, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1685224800, 'todate': 1685829600}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 14
# Fetched 14 questions on page 30 for 28 May 2023.
# Total questions collected so far: 49686
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 31 with params: {'page': 31, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1685224800, 'todate': 1685829600}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 9
# Fetched 9 questions on page 31 for 28 May 2023.
# Total questions collected so far: 49695
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 32 with params: {'page': 32, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1685224800, 'todate': 1685829600}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 13
# Fetched 13 questions on page 32 for 28 May 2023.
# Total questions collected so far: 49708
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 33 with params: {'page': 33, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1685224800, 'todate': 1685829600}
# HTTP error 400 occurred: 400 Client Error: Bad Request for url: https://api.stackexchange.com/2.3/questions?page=33&pagesize=100&order=desc&sort=votes&site=stackoverflow&filter=withbody&key=rl_Vssw9iwuVvjuT8agzZnVhH9J3&fromdate=1685224800&todate=1685829600. Retrying in 300 seconds...
# Total questions fetched (before filtering): 100
# Total questions after filtering: 10
# Fetched 10 questions on page 33 for 28 May 2023.
# Total questions collected so far: 49718
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 34 with params: {'page': 34, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1685224800, 'todate': 1685829600}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 13
# Fetched 13 questions on page 34 for 28 May 2023.
# Total questions collected so far: 49731
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 35 with params: {'page': 35, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1685224800, 'todate': 1685829600}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 11
# Fetched 11 questions on page 35 for 28 May 2023.
# Total questions collected so far: 49742
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 36 with params: {'page': 36, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1685224800, 'todate': 1685829600}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 8
# Fetched 8 questions on page 36 for 28 May 2023.
# Total questions collected so far: 49750
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 37 with params: {'page': 37, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1685224800, 'todate': 1685829600}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 11
# Fetched 11 questions on page 37 for 28 May 2023.
# Total questions collected so far: 49761
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 38 with params: {'page': 38, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1685224800, 'todate': 1685829600}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 9
# Fetched 9 questions on page 38 for 28 May 2023.
# Total questions collected so far: 49770
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 39 with params: {'page': 39, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1685224800, 'todate': 1685829600}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 14
# Fetched 14 questions on page 39 for 28 May 2023.
# Total questions collected so far: 49784
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 40 with params: {'page': 40, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1685224800, 'todate': 1685829600}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 11
# Fetched 11 questions on page 40 for 28 May 2023.
# Total questions collected so far: 49795
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 41 with params: {'page': 41, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1685224800, 'todate': 1685829600}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 9
# Fetched 9 questions on page 41 for 28 May 2023.
# Total questions collected so far: 49804
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 42 with params: {'page': 42, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1685224800, 'todate': 1685829600}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 15
# Fetched 15 questions on page 42 for 28 May 2023.
# Total questions collected so far: 49819
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 43 with params: {'page': 43, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1685224800, 'todate': 1685829600}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 12
# Fetched 12 questions on page 43 for 28 May 2023.
# Total questions collected so far: 49831
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 44 with params: {'page': 44, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1685224800, 'todate': 1685829600}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 9
# Fetched 9 questions on page 44 for 28 May 2023.
# Total questions collected so far: 49840
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 45 with params: {'page': 45, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1685224800, 'todate': 1685829600}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 7
# Fetched 7 questions on page 45 for 28 May 2023.
# Total questions collected so far: 49847
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 46 with params: {'page': 46, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1685224800, 'todate': 1685829600}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 10
# Fetched 10 questions on page 46 for 28 May 2023.
# Total questions collected so far: 49857
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 47 with params: {'page': 47, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1685224800, 'todate': 1685829600}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 12
# Fetched 12 questions on page 47 for 28 May 2023.
# Total questions collected so far: 49869
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 48 with params: {'page': 48, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1685224800, 'todate': 1685829600}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 12
# Fetched 12 questions on page 48 for 28 May 2023.
# Total questions collected so far: 49881
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 49 with params: {'page': 49, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1685224800, 'todate': 1685829600}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 17
# Fetched 17 questions on page 49 for 28 May 2023.
# Total questions collected so far: 49898
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 50 with params: {'page': 50, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1685224800, 'todate': 1685829600}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 15
# Fetched 15 questions on page 50 for 28 May 2023.
# Total questions collected so far: 49913
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 51 with params: {'page': 51, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1685224800, 'todate': 1685829600}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 16
# Fetched 16 questions on page 51 for 28 May 2023.
# Total questions collected so far: 49929
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 52 with params: {'page': 52, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1685224800, 'todate': 1685829600}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 9
# Fetched 9 questions on page 52 for 28 May 2023.
# Total questions collected so far: 49938
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 53 with params: {'page': 53, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1685224800, 'todate': 1685829600}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 13
# Fetched 13 questions on page 53 for 28 May 2023.
# Total questions collected so far: 49951
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 54 with params: {'page': 54, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1685224800, 'todate': 1685829600}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 3
# Fetched 3 questions on page 54 for 28 May 2023.
# Total questions collected so far: 49954
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 55 with params: {'page': 55, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1685224800, 'todate': 1685829600}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 22
# Fetched 22 questions on page 55 for 28 May 2023.
# Total questions collected so far: 49976
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 56 with params: {'page': 56, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1685224800, 'todate': 1685829600}
# HTTP error 400 occurred: 400 Client Error: Bad Request for url: https://api.stackexchange.com/2.3/questions?page=56&pagesize=100&order=desc&sort=votes&site=stackoverflow&filter=withbody&key=rl_Vssw9iwuVvjuT8agzZnVhH9J3&fromdate=1685224800&todate=1685829600. Retrying in 300 seconds...
# Total questions fetched (before filtering): 100
# Total questions after filtering: 10
# Fetched 10 questions on page 56 for 28 May 2023.
# Total questions collected so far: 49986
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 57 with params: {'page': 57, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1685224800, 'todate': 1685829600}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 11
# Fetched 11 questions on page 57 for 28 May 2023.
# Total questions collected so far: 49997
# Pausing for 10 seconds to respect rate limits.
# Sending request for page 58 with params: {'page': 58, 'pagesize': 100, 'order': 'desc', 'sort': 'votes', 'site': 'stackoverflow', 'filter': 'withbody', 'key': 'rl_Vssw9iwuVvjuT8agzZnVhH9J3', 'fromdate': 1685224800, 'todate': 1685829600}
# Total questions fetched (before filtering): 100
# Total questions after filtering: 8
# Fetched 8 questions on page 58 for 28 May 2023.
# Total questions collected so far: 50005
# Reached the maximum number of questions to fetch.
# Collected 50005 questions and saved to filtered_questions_year_n_1.csv

# %% [markdown]
# client id : 29476
# client secret : f*qvwypgwfHuuUzVJ4abow((
# key : rl_Vssw9iwuVvjuT8agzZnVhH9J3
# code : bOaC6F5f5Ct57Bcd7j0gPA))
